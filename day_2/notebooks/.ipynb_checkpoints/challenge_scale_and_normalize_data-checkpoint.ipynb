# %% [markdown]
# # Get our environment setup

# %%
import numpy as np
import pandas as pd

# for Box-Cox Transformation
from scipy import stats

# for min_max scaling
from mlxtend.preprocessing import minmax_scaling

# plotting modules
import seaborn as sns
import matplotlib.pyplot as plt

# read in all the data
kickstarters_2017 = pd.read_csv("../input/ks-projects-201801.csv")

# set seed for reproducibility
np.random.seed(0)

# %%
original_data = np.random.exponential(size=100)

scaled_data = minmax_scaling(original_data, columns=[0])

fig, ax = plt.subplots(1,2)
sns.distplot(original_data, ax=ax[0])
ax[0].set_title("original data")
sns.distplot(scaled_data, ax=ax[1])
ax[1].set_title("scaled data")
# Out:
# Text(0.5,1,u'scaled data')

# %% [markdown]
# # Normalization

# %%
normalized_data = stats.boxcox(original_data)

fig, ax = plt.subplots(1,2)
sns.distplot(original_data, ax=ax[0])
ax[0].set_title("original data")
sns.distplot(normalized_data[0], ax=ax[1])
ax[1].set_title("normalized data")
# Out:
# Text(0.5,1,u'normalized data')

# %%
original_data
# Out:
# array([1.66515474, 0.42800515, 0.23756554, 0.06121944, 2.08769025,
#        2.50772237, 0.12796995, 0.40717719, 0.19282299, 0.12318337,
#        2.30125341, 0.05855884, 3.93660588, 0.10142478, 1.99121566,
#        0.83587757, 0.45873534, 0.41907081, 1.41619349, 0.37771371,
#        1.07095505, 0.72841397, 0.66352167, 2.31427486, 0.80888369,
#        1.75366402, 1.29307194, 0.03932025, 1.48329019, 0.24445689,
#        2.33458824, 0.04387268, 0.40507324, 0.10506383, 0.64547977,
#        1.71492308, 0.3540888 , 0.16361941, 0.40087621, 1.68136441,
#        0.15126945, 0.25794523, 0.07133701, 1.22318975, 0.50291242,
#        0.37228178, 1.26807192, 0.40943931, 1.30111266, 1.68847785,
#        0.24546948, 3.64270974, 0.17716442, 0.34367539, 0.19820132,
#        0.42389234, 0.65404357, 0.73851254, 1.92145395, 2.20226846,
#        0.24859452, 0.97522905, 0.11821619, 0.61428029, 0.38910006,
#        0.38052971, 0.65890855, 1.30869514, 0.07169222, 2.1133983 ,
#        1.32732296, 0.19419099, 2.79952275, 0.70585199, 8.56103075,
#        0.21972375, 0.76552047, 0.34283973, 0.36265501, 0.89419999,
#        2.54745122, 1.63610974, 1.28714211, 0.81910454, 2.55488076,
#        0.67798552, 2.07014234, 1.79565692, 0.24058903, 1.47501831,
#        0.01224583, 0.38983225, 0.26080316, 0.70696817, 1.33504308,
#        0.10278203, 0.72344599, 2.78728858, 0.25960858, 1.13054003])

# %%
print max(original_data)
print min(original_data)
# Out:
# 8.56103075405615
# 0.01224583201384799

# %%
sns.distplot(original_data, bins=9, kde=False, rug=True)

# %%
sns.rugplot(original_data)

# %% [markdown]
# # Practice Scaling

# %%
usd_goal = kickstarters_2017.usd_goal_real

scaled_data = minmax_scaling(usd_goal, columns=[0])

fig, ax = plt.subplots(1,2)
sns.distplot(usd_goal, ax=ax[0])
ax[0].set_title("original data")
sns.distplot(scaled_data, ax=ax[1])
ax[1].set_title("scaled data")
# Out:
# Text(0.5,1,u'scaled data')

# %%
print min(usd_goal)
print max(usd_goal)
# Out:
# 0.01
# 166361390.71

# %%
print usd_goal.shape
# Out:
# (378661,)

# %%
# a close look to the graph of original data

fig, ax = plt.subplots(2,1)
# ax[0].set_xlim([0, 5000000])
ax[0].set_ylim([0, 100])
sns.distplot(usd_goal, kde=False, ax=ax[0])
ax[0].set_title("limited y-axis")

sns.distplot(usd_goal, kde=False, ax=ax[1])
# ax[1].set_title("original graph")

# %%
# a close look to the graph

fig, ax = plt.subplots(2,1)
# ax[0].set_xlim([0, 5000000])
ax[0].set_ylim([0, 100])
sns.distplot(, kde=False, ax=ax[0])
ax[0].set_title("limited y-axis")

sns.distplot(usd_goal, kde=False, ax=ax[1])
# ax[1].set_title("original graph")
